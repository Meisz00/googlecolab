# %% [markdown]
# <a href="https://colab.research.google.com/github/Meisz00/googlecolab/blob/main/Copy_of_Latihan_Soal_Data_Cleaning_Maysa_Fix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
Data = pd.read_csv("online_retail.csv")
Df = pd.DataFrame(Data)
Df
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %% [markdown]
# 3. Keluarkan output dengan menghapus nilai data yang berisi null atau nan

# %%
Df.dropna(inplace = True)
Df
# Out:
#        order_id product_code                       product_name  quantity  \
# 0        493410      TEST001            This is a test product.         5
# 1       C493411        21539            RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001            This is a test product.         5
# 6        493414        21844                     RETRO SPOT MUG        36
# 7        493414        21533          RETRO SPOT LARGE MILK JUG        12
# ...         ...          ...                                ...       ...
# 461740   539988        84380  SET OF 3 BUTTERFLY COOKIE CUTTERS         1
# 461741   539988       84849D              HOT BATHS SOAP HOLDER         1
# 461742   539988       84849B             FAIRY SOAP SOAP HOLDER         1
# 461743   539988        22854        CREAM SWEETHEART EGG HOLDER         2
# 461744   539988       47559B                TEA TIME OVEN GLOVE         2
#
#                  order_date  price  customer_id
# ...

# %% [markdown]
# 4. Keluarkan output dengan mengganti data yang berisi null atau nan

# %%
Df.fillna(0, inplace = True)
Df
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %% [markdown]
# 5. Bagaimana cara mengisi data yang bernilai null atau nan dengan data yang sebelumnya ?

# %%
Df.fillna(method = "ffill")
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %% [markdown]
# 6. Bagaimana cara mengganti data yang berisi null atau nan, namun hanya data yang pertama saja yang diganti?

# %%
Df.fillna(method = "ffill", limit = 1)
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %% [markdown]
# 7. Apa yang ditampilkan dari sintaks dibawah ini ?
#
#                    df.fillna(value=values, limit=10)

# %%
Df.fillna(value = 1, limit = 10)
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %% [markdown]
# 8. Apa yang ditampilkan output dibawah ini ?
#                   df.fillna(method="ffill")

# %%
Df.fillna(method = "ffill")
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %% [markdown]
# 9. Apa yang ditampilkan output dibawah ini?
#
#                  df.fillna(108975)

# %%
Df.fillna(108975)
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %% [markdown]
# 10. Apa yang ditampilkan output di bawah ini ?
#
#                 df.dropna(how='all',inplace = True)

# %%
Df.dropna(how='all', inplace = True)
Df
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %% [markdown]
# 12. Apa yang dimaksud dengan data cleaning?

# %% [markdown]
# Data cleaning adalah suatu proses pembersihan data untuk mendapat data-data yang dibutuhkan tanpa adanya data kotor.

# %% [markdown]
# 13. Apa keuntungan utama dari melakukan data cleaning?

# %% [markdown]
# Keuntungan dari penggunaan data cleaning adalah membantu proses pengolahan data sehingga dapat berjalan lancar.

# %% [markdown]
# 14. Apa yang dimaksud dengan missing values?

# %% [markdown]
# Missing values yaitu ketika data tidak memiliki nilai.

# %% [markdown]
# 15. Bagaimana cara mengidentifikasi missing values dalam DataFrame?

# %%
pd.isna(Df)
# Out:
#         order_id  product_code  product_name  quantity  order_date  price  \
# 0          False         False         False     False       False  False
# 1          False         False         False     False       False  False
# 2          False         False         False     False       False  False
# 3          False         False         False     False       False  False
# 4          False         False         False     False       False  False
# ...          ...           ...           ...       ...         ...    ...
# 461768     False         False         False     False       False  False
# 461769     False         False         False     False       False  False
# 461770     False         False         False     False       False  False
# 461771     False         False         False     False       False  False
# 461772     False         False         False     False       False  False
#
#         customer_id
# 0             False
# 1             False
# ...

# %% [markdown]
# 16. Bagaimana cara menghitung jumlah missing values dalam setiap kolom DataFrame?

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461773 entries, 0 to 461772
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      461773 non-null  object
#  1   product_code  461773 non-null  object
#  2   product_name  459055 non-null  object
#  3   quantity      461773 non-null  int64
#  4   order_date    461773 non-null  object
#  5   price         461773 non-null  float64
#  6   customer_id   360853 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 24.7+ MB

# %% [markdown]
# 17. Bagaimana cara menghapus baris yang mengandung missing values dalam DataFrame?

# %%
Df.dropna()
# Out:
#        order_id product_code                       product_name  quantity  \
# 0        493410      TEST001            This is a test product.         5
# 1       C493411        21539            RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001            This is a test product.         5
# 6        493414        21844                     RETRO SPOT MUG        36
# 7        493414        21533          RETRO SPOT LARGE MILK JUG        12
# ...         ...          ...                                ...       ...
# 461740   539988        84380  SET OF 3 BUTTERFLY COOKIE CUTTERS         1
# 461741   539988       84849D              HOT BATHS SOAP HOLDER         1
# 461742   539988       84849B             FAIRY SOAP SOAP HOLDER         1
# 461743   539988        22854        CREAM SWEETHEART EGG HOLDER         2
# 461744   539988       47559B                TEA TIME OVEN GLOVE         2
#
#                  order_date  price  customer_id
# ...

# %% [markdown]
# 18. Bagaimana cara mengganti missing values dengan nilai tertentu dalam DataFrame?

# %%
Df.fillna(1)
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  price  customer_id
# 0       2010-01-04 09:24:00   4.50      12346.0
# ...

# %% [markdown]
# 19. Apa yang dimaksud dengan duplicated values?

# %% [markdown]
# Duplicated values adalah data dalam dataframe yang terduplikasi.

# %% [markdown]
# 20. Bagaimana cara mengidentifikasi duplicated values dalam DataFrame?

# %%
Df.drop_duplicates()
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# 6        493414        21844                   RETRO SPOT MUG        36
# ...         ...          ...                              ...       ...
# 460369   539746          DOT                   DOTCOM POSTAGE         1
# 460381   539747          DOT                   DOTCOM POSTAGE         1
# 460388   539748          DOT                   DOTCOM POSTAGE         1
# 460833   539856            M                           Manual         1
# 461365   539958          DOT                   DOTCOM POSTAGE         1
#
#                  order_date    price  customer_id
# 0       2010-01-04 09:24:00     4.50      12346.0
# ...

# %% [markdown]
# 21. Bagaimana cara menghitung jumlah duplicated values dalam DataFrame?

# %%
Df.sum()
# Out:
# <ipython-input-87-311eab9f9c71>:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Df.sum()
# order_id        493410C493411493413493413493414493414493414C49...
# product_code    TEST001215392172484578218442152721531215272210...
# quantity                                                    41281
# order_date      2010-01-04 09:24:002010-01-04 09:43:002010-01-...
# price                                                  248482.061
# customer_id                                             7655566.0
# dtype: object

# %% [markdown]
# 22. Bagaimana cara menghapus duplicated values dalam DataFrame?

# %%
Df.drop_duplicates(subset = 'price', keep = "first", inplace = True)
Df
# Out:
#        order_id product_code                     product_name  quantity  \
# 0        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# 6        493414        21844                   RETRO SPOT MUG        36
# ...         ...          ...                              ...       ...
# 460369   539746          DOT                   DOTCOM POSTAGE         1
# 460381   539747          DOT                   DOTCOM POSTAGE         1
# 460388   539748          DOT                   DOTCOM POSTAGE         1
# 460833   539856            M                           Manual         1
# 461365   539958          DOT                   DOTCOM POSTAGE         1
#
#                  order_date    price  customer_id
# 0       2010-01-04 09:24:00     4.50      12346.0
# ...

# %% [markdown]
# 23. Bagaimana cara mengganti nilai dalam DataFrame berdasarkan kondisi tertentu?

# %%
Df.replace(0, 10)
# Out:
#        order_id product_code                     product_name  quantity  \
# x        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# 6        493414        21844                   RETRO SPOT MUG        36
# ...         ...          ...                              ...       ...
# 460369   539746          DOT                   DOTCOM POSTAGE         1
# 460381   539747          DOT                   DOTCOM POSTAGE         1
# 460388   539748          DOT                   DOTCOM POSTAGE         1
# 460833   539856            M                           Manual         1
# 461365   539958          DOT                   DOTCOM POSTAGE         1
#
#                  order_date  cost  customer_id
# x       2010-01-04 09:24:00     4      12346.0
# ...

# %% [markdown]
# 24. Bagaimana cara mengubah tipe data kolom dalam DataFrame?

# %%
Df['price'] = Df['price'].astype(int)
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461773 entries, 0 to 461772
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      461773 non-null  object
#  1   product_code  461773 non-null  object
#  2   product_name  459055 non-null  object
#  3   quantity      461773 non-null  int64
#  4   order_date    461773 non-null  object
#  5   price         461773 non-null  int64
#  6   customer_id   360853 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 24.7+ MB

# %% [markdown]
# 25. Bagaimana sintaks untuk mengganti nama kolom 'old_column' menjadi 'new_column' dalam DataFrame?

# %%
Df.rename(columns={"price":"cost"})
Df
# Out:
#        order_id product_code                     product_name  quantity  \
# x        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  cost  customer_id
# x       2010-01-04 09:24:00     4      12346.0
# ...

# %% [markdown]
# 26.  Bagaimana sintaks untuk mengganti nama indeks 'old_index' menjadi 'new_index' dalam DataFrame?

# %%
Df.rename(index = {0:"x"})
Df
# Out:
#        order_id product_code                     product_name  quantity  \
# x        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  cost  customer_id
# x       2010-01-04 09:24:00     4      12346.0
# ...

# %% [markdown]
# 27. Bagaimana sintaks untuk mengganti nama kolom 'old_column' menjadi 'new_column' dan nama indeks 'old_index' menjadi 'new_index' dalam DataFrame?

# %%
Df.rename(index = {0:"x"}, columns={"price":"cost"})
Df
# Out:
#        order_id product_code                     product_name  quantity  \
# x        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  cost  customer_id
# x       2010-01-04 09:24:00     4      12346.0
# ...

# %% [markdown]
# 28. Bagaimana sintaks untuk mengganti nama kolom dengan menggunakan fungsi pengubahan nama dalam DataFrame?

# %%
Df.rename(columns={"price":"cost"})
Df
# Out:
#        order_id product_code                     product_name  quantity  \
# x        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  cost  customer_id
# x       2010-01-04 09:24:00     4      12346.0
# ...

# %% [markdown]
# 29.  Bagaimana sintaks untuk mengganti nama indeks dengan menggunakan fungsi pengubahan nama dalam DataFrame?

# %%
Df.rename(index = {0:"x"})
Df
# Out:
#        order_id product_code                     product_name  quantity  \
# x        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  cost  customer_id
# x       2010-01-04 09:24:00     4      12346.0
# ...

# %% [markdown]
# 30. Anda memiliki DataFrame yang berisi data penjualan produk di toko online. Kolom-kolomnya adalah 'Product_ID', 'Product_Name', 'Price', dan 'Quantity'. Namun, Anda ingin mengganti nama kolom 'Product_Name' menjadi 'Item_Name' agar lebih sesuai dengan konteks data yang ada.

# %%
Df.rename(columns={"product_name":"item_name"})
Df
# Out:
#        order_id product_code                        item_name  quantity  \
# x        493410      TEST001          This is a test product.         5
# 1       C493411        21539          RETRO SPOTS BUTTER DISH        -1
# 2        493412      TEST001          This is a test product.         5
# 3        493413        21724  PANDA AND BUNNIES STICKER SHEET         1
# 4        493413        84578   ELEPHANT TOY WITH BLUE T-SHIRT         1
# ...         ...          ...                              ...       ...
# 461768   539991        21618   4 WILDFLOWER BOTANICAL CANDLES         1
# 461769   539991        72741            GRAND CHOCOLATECANDLE         4
# 461770   539992        21470    FLOWER VINE RAFFIA FOOD COVER         1
# 461771   539992        22258          FELT FARM ANIMAL RABBIT         1
# 461772   539992        21155            RED RETROSPOT PEG BAG         1
#
#                  order_date  cost  customer_id
# x       2010-01-04 09:24:00     4      12346.0
# ...
